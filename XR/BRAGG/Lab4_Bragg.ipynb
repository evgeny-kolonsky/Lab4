# %% [markdown]
# <a href="https://colab.research.google.com/github/evgeny-kolonsky/Lab4/blob/main/XR/BRAGG/Lab4_Bragg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab4 XR Bragg experiment
#
# Evgeny Kolonsky 2026
#
# Wavelengths
# $$
# n \lambda = 2 d \sin \theta
# $$
#
# Energy
# $$
# E = \frac{hc}{\lambda}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
from scipy.constants import c, h, electron_volt as eV

# %% [markdown]
# [$K_\alpha, K_\beta$ reference table](https://physics.nist.gov/PhysRefData/XrayTrans/Html/search.html)

# %%
URL = 'https://raw.githubusercontent.com/evgeny-kolonsky/Lab4/refs/heads/main/XR/BRAGG/'
crystal = 'LF1'
lamp = 'Mo4'
filename = URL + f'{lamp}_{crystal}_d2.txt'
d = 201e-12 #m
theta, count = np.genfromtxt(filename, skip_header=3, unpack=True)
theta_rad = theta * np.pi / 180
peaks, _ = find_peaks(count, prominence=100)
plt.plot(theta, count,  label=lamp)
plt.plot(theta[peaks], count[peaks], 'x')

plt.yscale('log')
plt.xlabel('Theta crystal, grad')
plt.ylabel('Count rate, #/s')
plt.grid()
plt.legend()
plt.xlim(5, 45)
# Out:
# (5.0, 45.0)

# %%
mask = (theta > 5) & (theta < 15)
n = 1
theta_rad = theta * np.pi / 180
E = n * h * c / (2 * d * np.sin(theta_rad)) / eV
plt.plot(E[mask] / 1000, count[mask],  label=f'{n=}')

mask = (theta > 15) & (theta < 25)
n = 2
theta_rad = theta * np.pi / 180
E = n * h * c / (2 * d * np.sin(theta_rad)) / eV
plt.plot(E[mask] / 1000, count[mask],  label=f'{n=}')

mask = (theta > 25) & (theta < 35)
n = 3
theta_rad = theta * np.pi / 180
E = n * h * c / (2 * d * np.sin(theta_rad)) / eV
plt.plot(E[mask] / 1000, count[mask],  label=f'{n=}')

mask = (theta > 35) & (theta < 45)
n = 4
theta_rad = theta * np.pi / 180
E = n * h * c / (2 * d * np.sin(theta_rad)) / eV
plt.plot(E[mask] / 1000, count[mask],   label=f'{n=}')

#peaks, _ = find_peaks(count, prominence=100)
#plt.plot(E[peaks]/1000, count[peaks], 'o')

# https://physics.nist.gov/cgi-bin/XrayTrans/search.pl?element=Mo&lower=&upper=&units=eV
expected_lines = [17374, 17479, 19590, 19608]


for line in expected_lines:
    plt.axvline(x=line/1000, color='k', linestyle='--')


plt.yscale('log')
plt.xlabel('Energy, keV')
plt.ylabel('Count rate, #/s')
plt.grid()
plt.legend()
plt.xlim(16, 21)
# Out:
# (16.0, 21.0)

# %%
URL = 'https://raw.githubusercontent.com/evgeny-kolonsky/Lab4/refs/heads/main/XR/BRAGG/'
crystal = 'LF1'
d = 201e-12 #m
for lamp in ['Mo1', 'Mo2', 'Mo3', 'Mo4']:
  filename = URL + f'{lamp}_{crystal}_d2.txt'
  theta, count = np.genfromtxt(filename, skip_header=3, unpack=True)
  theta_rad = theta * np.pi / 180
  peaks, _ = find_peaks(count, prominence=100)
  plt.plot(theta, count,  label=lamp)
  plt.plot(theta[peaks], count[peaks], 'x')

plt.yscale('log')
plt.xlabel('Theta crystal, grad')
plt.ylabel('Count rate, #/s')
plt.grid()
plt.legend()
plt.xlim(5, 45)
# Out:
# (5.0, 45.0)

# %% [markdown]
# ## Lamps `Mo3` and `Mo4` are performing slightly better than `Mo1` or `Mo2`.

# %%
lamp = 'Mo3'
for crystal in ['LF1', 'LF2', 'LF3']:
  filename = URL + f'{lamp}_{crystal}_d2.txt'
  theta, count = np.genfromtxt(filename, skip_header=3, unpack=True)
  theta_rad = theta * np.pi / 180
  peaks, _ = find_peaks(count, prominence=100)
  plt.plot(theta, count,  label=crystal)
  #plt.plot(theta[peaks], count[peaks], 'x')

plt.yscale('log')
plt.xlabel('Theta crystal, grad')
plt.ylabel('Count rate, #/s')
plt.grid()
plt.legend()
plt.xlim(5, 45)
# Out:
# (5.0, 45.0)

# %%
lamp = 'Mo2'
for crystal in ['LF1', 'LF3']:
  filename = URL + f'{lamp}_{crystal}_d2.txt'
  theta, count = np.genfromtxt(filename, skip_header=3, unpack=True)
  theta_rad = theta * np.pi / 180
  peaks, _ = find_peaks(count, prominence=100)
  plt.plot(theta, count,  label=crystal)
  #plt.plot(theta[peaks], count[peaks], 'x')

plt.yscale('log')
plt.xlabel('Theta crystal, grad')
plt.ylabel('Count rate, #/s')
plt.grid()
plt.legend()
plt.xlim(5, 45)
# Out:
# (5.0, 45.0)

# %% [markdown]
# ## Crystal `LiF1` is performing better than `LiF2` or `LiF3`.

# %%
lamp = 'Mo3'
d = 330e-12 #m

for crystal in ['KB1', 'KB2']:
  filename = URL + f'{lamp}_{crystal}_d2.txt'
  theta, count = np.genfromtxt(filename, skip_header=3, usecols=[0, 1], unpack=True, encoding='latin1')
  theta_rad = theta * np.pi / 180
  peaks, _ = find_peaks(count, prominence=100)
  plt.plot(theta, count,  label=crystal)
  plt.plot(theta[peaks], count[peaks], 'x')

plt.yscale('log')
plt.xlabel('Theta crystal, grad')
plt.ylabel('Count rate, #/s')
plt.grid()
plt.legend()
plt.xlim(5, 45)
# Out:
# (5.0, 45.0)

# %% [markdown]
# ## Crystal `KB2` is performing better than `KB1`.

# %%
crystal = 'KB1'
d = 330e-12 #m
lamp = 'Cu'
filename = URL + f'{lamp}_{crystal}_d2.txt'
print(filename)
theta, count = np.genfromtxt(filename, skip_header=3, unpack=True, encoding='latin1')
theta_rad = theta * np.pi / 180
peaks, _ = find_peaks(count, prominence=100)
plt.plot(theta, count,  label=lamp)
plt.plot(theta[peaks], count[peaks], 'x')

k_edge = 8.1 # degrees
l = 2 * d * np.sin(k_edge * np.pi / 180)
E = h * c / l
plt.axvline(x=k_edge, color='gray', ls='--', label=f'Br k-edge {E/eV /1e3:.3f} keV')

plt.yscale('log')
plt.xlabel('Theta crystal, grad')
plt.ylabel('Count rate, #/s')
plt.grid()
plt.legend()
plt.xlim(5, 45)

for peak in peaks:
  if theta[peak] < 15:
    n = 1
  elif theta[peak] < 30:
    n = 2
  else:
    n = 3
  l = 2 * d * np.sin(theta_rad[peak]) / n
  E = h * c / l
  print(f'Angle {theta[peak]:.2f} deg at order {n}, wavelength {l*1e10:.3f} Å, Energy {E/eV /1e3:.3f} keV')
# Out:
# https://raw.githubusercontent.com/evgeny-kolonsky/Lab4/refs/heads/main/XR/BRAGG/Cu_KB1_d2.txt
# Angle 12.30 deg at order 1, wavelength 1.406 Å, Energy 8.818 keV
# Angle 13.60 deg at order 1, wavelength 1.552 Å, Energy 7.989 keV
# Angle 25.10 deg at order 2, wavelength 1.400 Å, Energy 8.857 keV
# Angle 27.90 deg at order 2, wavelength 1.544 Å, Energy 8.029 keV
# Angle 39.30 deg at order 3, wavelength 1.393 Å, Energy 8.898 keV
# Angle 44.50 deg at order 3, wavelength 1.542 Å, Energy 8.040 keV

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Ferrum
#
# $K_\alpha, K_\beta$ [ref](https://physics.nist.gov/cgi-bin/XrayTrans/search.pl?element=Fe&lower=&upper=&units=eV)

# %%
crystal = 'KB1'
d = 330e-12 #m
lamp = 'Fe'
filename = URL + f'{lamp}_{crystal}_d2.txt'
print(filename)
theta, count = np.genfromtxt(filename, skip_header=3, unpack=True, encoding='latin1')
theta_rad = theta * np.pi / 180
peaks, _ = find_peaks(count, prominence=100)
plt.plot(theta, count,  label=lamp)
plt.plot(theta[peaks], count[peaks], 'x')


k_edge = 8.0 # degrees
l = 2 * d * np.sin(k_edge * np.pi / 180)
E = h * c / l
plt.axvline(x=k_edge, color='gray', ls='--', label=f'Br k-edge {E/eV /1e3:.3f} keV')

plt.yscale('log')
plt.xlabel('Theta crystal, grad')
plt.ylabel('Count rate, #/s')
plt.grid()
plt.legend()
plt.xlim(5, 45)

for peak in peaks:
  if theta[peak] < 20:
    n = 1
  elif theta[peak] < 40:
    n = 2
  else:
    n = 3
  l = 2 * d * np.sin(theta_rad[peak]) / n
  E = h * c / l
  print(f'Angle {theta[peak]:.2f} deg at order {n}, wavelength {l*1e10:.3f} Å, Energy {E/eV /1e3:.3f} keV')
# Out:
# https://raw.githubusercontent.com/evgeny-kolonsky/Lab4/refs/heads/main/XR/BRAGG/Fe_KB1_d2.txt
# Angle 8.60 deg at order 1, wavelength 0.987 Å, Energy 12.563 keV
# Angle 15.50 deg at order 1, wavelength 1.764 Å, Energy 7.029 keV
# Angle 17.10 deg at order 1, wavelength 1.941 Å, Energy 6.389 keV
# Angle 32.20 deg at order 2, wavelength 1.758 Å, Energy 7.051 keV
# Angle 35.90 deg at order 2, wavelength 1.935 Å, Energy 6.407 keV
# Angle 61.50 deg at order 3, wavelength 1.933 Å, Energy 6.413 keV

# %%
crystal = 'KB1'
d = 330e-12 #m
lamp = 'Mo3'
filename = URL + f'{lamp}_{crystal}_d2.txt'
print(filename)
theta, count = np.genfromtxt(filename, skip_header=3, unpack=True, encoding='latin1')
theta_rad = theta * np.pi / 180
peaks, _ = find_peaks(count, prominence=100)
plt.plot(theta, count,  label=lamp)
plt.plot(theta[peaks], count[peaks], 'x')

k_edge = 8.1 # degrees
l = 2 * d * np.sin(k_edge * np.pi / 180)
E = h * c / l
plt.axvline(x=k_edge, color='gray', ls='--', label=f'Br k-edge {E/eV /1e3:.3f} keV')

plt.yscale('log')
plt.xlabel('Theta crystal, grad')
plt.ylabel('Count rate, #/s')
plt.grid()
plt.legend()
plt.xlim(5, 45)

for peak in peaks:
  if theta[peak] < 7:
    n = 1
  elif theta[peak] < 15:
    n = 2
  else:
    n = 3
  l = 2 * d * np.sin(theta_rad[peak]) / n
  E = h * c / l
  print(f'Angle {theta[peak]:.2f} deg at order {n}, wavelength {l*1e10:.3f} Å, Energy {E/eV /1e3:.3f} keV')
# Out:
# https://raw.githubusercontent.com/evgeny-kolonsky/Lab4/refs/heads/main/XR/BRAGG/Mo3_KB1_d2.txt
# Angle 5.60 deg at order 1, wavelength 0.644 Å, Energy 19.251 keV
# Angle 6.30 deg at order 1, wavelength 0.724 Å, Energy 17.119 keV
# Angle 12.50 deg at order 2, wavelength 0.714 Å, Energy 17.359 keV

# %% [markdown]
# <a href="https://colab.research.google.com/github/evgeny-kolonsky/Lab4/blob/main/Hall/Hall_contacts_R_AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab4 Hall samples: contacts resistance
#
# Evgeny Kolonsky 2025
#
# v.0.1.2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Sample 12

# %%
# Resistance
R1 = 39 # Ohm - horizontal
R2 = 44 # Ohm - vertical

# %% [markdown]
# ## Sample 11

# %%
R1 = 63 # Ohm
R2 = 39

# %% [markdown]
# ## Sample 14

# %%
R1 = 40 # Ohm
R2 = 45

# %% [markdown]
# ## Sample 24

# %%
R1 = 53 # Ohm
R2 = 51

# %% [markdown]
# ## Sample 13

# %%
R1 = 36 # Ohm
R2 = 34

# %% [markdown]
# ## Sample 21

# %%
R1, R2 = 47, 56 # Ohm

# %% [markdown]
# ## Sample 22

# %%
R1, R2 = 47, 54 # Ohm

# %% [markdown]
# ## Sample 23

# %%
R1, R2 = 46, 50 # Ohm

# %% [markdown]
# # Sample 12 AC when Ip=0

# %%
t, v, _ = np.loadtxt('12.csv', skiprows=1, delimiter=',').T

# %%
plt.plot(t*1e3, v*1e3, '.')
plt.grid()
plt.xlabel('t, ms')
plt.ylabel('Voltage on Uh contacts, mV')
plt.show()
